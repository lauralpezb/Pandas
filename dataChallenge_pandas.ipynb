# %% [markdown]
# <a href="https://colab.research.google.com/github/lauralpezb/Pandas/blob/master/dataChallenge_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image
Image(filename='Manipulación de datos con Pandas.png', width=900)

# %% [markdown]
# # **Agenda** 📑
# - Pandas
# - Introducción a DataFrame
# - Sorting and subsetting
# - Agregar columnas
# - Resumen estadístico
# - Eliminar duplicados y value_counts()
# - Groupby
# - Pivot tables
# - Indices
# - .iloc[] y .loc[]
# - Visualización
# - Valores faltantes
# - CSV

# %%
Image(filename='logo_pandas.png', width=300)

# %% [markdown]
# Librería de Python especializada en el manejo y análisis de estructuras de datos.
#
# Basada en NumPy y MatplotLib
#
# https://pandas.pydata.org

# %%
import pandas as pd

# %% [markdown]
# # **DataFrame**

# %%
Image(filename='dataframe.png', width=300)

# %% [markdown]
# Vamos a crear un DataFrame con los datos de productos de un supermercado:
# - Categoria: Tipo de producto
# - Producto: Nombre del producto
# - Precio: Costo del producto
# - Fecha: Fecha de registro

# %% [markdown]
# Crear DataFrame apartir de diccionarios:

# %%
dic_to_dataf = {'Categoria':['Verduras','Lacteos','Carnes Frias','Panaderia','Panaderia','Panaderia'], 
                'Producto':['Pepino','Leche Entera','Salchichas','Almojábana','Pan con queso','Almojábana'],
                'Precio':[600,2300,4650,1200,1500,1200],
                'Fecha':['2021-01-02','2019-01-31','2020-05-25','2020-08-12','2020-11-03','2020-08-12']}

# %%
supermercado_to_dic = pd.DataFrame(dic_to_dataf) 
supermercado_to_dic
# Out:
#       Categoria       Producto  Precio       Fecha
# 0      Verduras         Pepino     600  2021-01-02
# 1       Lacteos   Leche Entera    2300  2019-01-31
# 2  Carnes Frias     Salchichas    4650  2020-05-25
# 3     Panaderia     Almojábana    1200  2020-08-12
# 4     Panaderia  Pan con queso    1500  2020-11-03
# 5     Panaderia     Almojábana    1200  2020-08-12

# %%
type(supermercado_to_dic)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Crear DataFrame apartir de listas:

# %%
list_to_dataf = [{'Categoria':'Verduras','Producto':'Pepino','Precio':600, 'Fecha':'2021-01-02'},
                 {'Categoria':'Lacteos','Producto':'Leche Entera','Precio':2300, 'Fecha':'2019-01-31'},
                 {'Categoria':'Carnes Frias','Producto':'Salchichas','Precio':4650, 'Fecha':'2020-05-25'},
                 {'Categoria':'Panaderia','Producto':'Almojábana','Precio':1200, 'Fecha':'2020-08-12'},
                 {'Categoria':'Panaderia','Producto':'Pan con queso','Precio':1500, 'Fecha':'2020-11-03'},
                 {'Categoria':'Panaderia','Producto':'Almojábana','Precio':1200, 'Fecha':'2020-08-12'}]

# %%
supermercado_to_list = pd.DataFrame(list_to_dataf) 
supermercado_to_list
# Out:
#       Categoria       Producto  Precio       Fecha
# 0      Verduras         Pepino     600  2021-01-02
# 1       Lacteos   Leche Entera    2300  2019-01-31
# 2  Carnes Frias     Salchichas    4650  2020-05-25
# 3     Panaderia     Almojábana    1200  2020-08-12
# 4     Panaderia  Pan con queso    1500  2020-11-03
# 5     Panaderia     Almojábana    1200  2020-08-12

# %%
type(supermercado_to_list)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## **Explorar un DataFrame** 🔍

# %%
supermercado_to_dic.head()
# Out:
#       Categoria       Producto  Precio       Fecha
# 0      Verduras         Pepino     600  2021-01-02
# 1       Lacteos   Leche Entera    2300  2019-01-31
# 2  Carnes Frias     Salchichas    4650  2020-05-25
# 3     Panaderia     Almojábana    1200  2020-08-12
# 4     Panaderia  Pan con queso    1500  2020-11-03

# %%
supermercado_to_dic.head(3)
# Out:
#       Categoria      Producto  Precio       Fecha
# 0      Verduras        Pepino     600  2021-01-02
# 1       Lacteos  Leche Entera    2300  2019-01-31
# 2  Carnes Frias    Salchichas    4650  2020-05-25

# %%
supermercado_to_dic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Categoria  6 non-null      object
#  1   Producto   6 non-null      object
#  2   Precio     6 non-null      int64
#  3   Fecha      6 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 320.0+ bytes

# %%
supermercado_to_dic.shape
# Out:
# (6, 4)

# %%
supermercado_to_dic.describe()
# Out:
#             Precio
# count     6.000000
# mean   1908.333333
# std    1452.727320
# min     600.000000
# 25%    1200.000000
# 50%    1350.000000
# 75%    2100.000000
# max    4650.000000

# %% [markdown]
# ## **Componentes de un DataFrame:** 🗃️

# %%
supermercado_to_dic.values
# Out:
# array([['Verduras', 'Pepino', 600, '2021-01-02'],
#        ['Lacteos', 'Leche Entera', 2300, '2019-01-31'],
#        ['Carnes Frias', 'Salchichas', 4650, '2020-05-25'],
#        ['Panaderia', 'Almojábana', 1200, '2020-08-12'],
#        ['Panaderia', 'Pan con queso', 1500, '2020-11-03'],
#        ['Panaderia', 'Almojábana', 1200, '2020-08-12']], dtype=object)

# %%
supermercado_to_dic.columns
# Out:
# Index(['Categoria', 'Producto', 'Precio', 'Fecha'], dtype='object')

# %%
supermercado_to_dic.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %% [markdown]
# # **Sorting and subsetting**

# %%
Image(filename='Sorting and subsetting.png', width=300)

# %% [markdown]
# ### Sorting:

# %%
supermercado_to_dic.sort_values('Categoria')
# Out:
#       Categoria       Producto  Precio       Fecha
# 2  Carnes Frias     Salchichas    4650  2020-05-25
# 1       Lacteos   Leche Entera    2300  2019-01-31
# 3     Panaderia     Almojábana    1200  2020-08-12
# 4     Panaderia  Pan con queso    1500  2020-11-03
# 5     Panaderia     Almojábana    1200  2020-08-12
# 0      Verduras         Pepino     600  2021-01-02

# %%
supermercado_to_dic.sort_values('Categoria', ascending = False)
# Out:
#       Categoria       Producto  Precio       Fecha
# 0      Verduras         Pepino     600  2021-01-02
# 3     Panaderia     Almojábana    1200  2020-08-12
# 4     Panaderia  Pan con queso    1500  2020-11-03
# 5     Panaderia     Almojábana    1200  2020-08-12
# 1       Lacteos   Leche Entera    2300  2019-01-31
# 2  Carnes Frias     Salchichas    4650  2020-05-25

# %%
supermercado_to_dic.sort_values(['Categoria','Precio'], ascending = [False,True])
# Out:
#       Categoria       Producto  Precio       Fecha
# 0      Verduras         Pepino     600  2021-01-02
# 3     Panaderia     Almojábana    1200  2020-08-12
# 5     Panaderia     Almojábana    1200  2020-08-12
# 4     Panaderia  Pan con queso    1500  2020-11-03
# 1       Lacteos   Leche Entera    2300  2019-01-31
# 2  Carnes Frias     Salchichas    4650  2020-05-25

# %% [markdown]
# ### Subsetting:

# %%
supermercado_to_dic['Producto']
# Out:
# 0           Pepino
# 1     Leche Entera
# 2       Salchichas
# 3       Almojábana
# 4    Pan con queso
# 5       Almojábana
# Name: Producto, dtype: object

# %%
supermercado_to_dic[['Categoria','Producto']]
# Out:
#       Categoria       Producto
# 0      Verduras         Pepino
# 1       Lacteos   Leche Entera
# 2  Carnes Frias     Salchichas
# 3     Panaderia     Almojábana
# 4     Panaderia  Pan con queso
# 5     Panaderia     Almojábana

# %%
supermercado_to_dic[supermercado_to_dic['Precio'] < 2000]
# Out:
#    Categoria       Producto  Precio       Fecha
# 0   Verduras         Pepino     600  2021-01-02
# 3  Panaderia     Almojábana    1200  2020-08-12
# 4  Panaderia  Pan con queso    1500  2020-11-03
# 5  Panaderia     Almojábana    1200  2020-08-12

# %%
supermercado_to_dic[(supermercado_to_dic['Precio'] < 1300) & (supermercado_to_dic['Categoria'] == 'Panaderia')]
# Out:
#    Categoria    Producto  Precio       Fecha
# 3  Panaderia  Almojábana    1200  2020-08-12
# 5  Panaderia  Almojábana    1200  2020-08-12

# %%
Refrigerar = supermercado_to_dic['Categoria'].isin(['Lacteos','Carnes Frias'])
supermercado_to_dic[Refrigerar]
# Out:
#       Categoria      Producto  Precio       Fecha
# 1       Lacteos  Leche Entera    2300  2019-01-31
# 2  Carnes Frias    Salchichas    4650  2020-05-25

# %% [markdown]
# # **Agregar columnas** 🗒️

# %%
Image(filename='columnas.png', width=300)

# %%
supermercado_to_dic['Descuento'] = supermercado_to_dic['Precio'] - (supermercado_to_dic['Precio']*0.2)
supermercado_to_dic.head()
# Out:
#       Categoria       Producto  Precio       Fecha  Descuento
# 0      Verduras         Pepino     600  2021-01-02      480.0
# 1       Lacteos   Leche Entera    2300  2019-01-31     1840.0
# 2  Carnes Frias     Salchichas    4650  2020-05-25     3720.0
# 3     Panaderia     Almojábana    1200  2020-08-12      960.0
# 4     Panaderia  Pan con queso    1500  2020-11-03     1200.0

# %%
supermercado_to_dic['Presentacion'] = ['Unidad','Bolsa','Paquete','Unidad','Unidad','Unidad']
supermercado_to_dic.head()
# Out:
#       Categoria       Producto  Precio       Fecha  Descuento Presentacion
# 0      Verduras         Pepino     600  2021-01-02      480.0       Unidad
# 1       Lacteos   Leche Entera    2300  2019-01-31     1840.0        Bolsa
# 2  Carnes Frias     Salchichas    4650  2020-05-25     3720.0      Paquete
# 3     Panaderia     Almojábana    1200  2020-08-12      960.0       Unidad
# 4     Panaderia  Pan con queso    1500  2020-11-03     1200.0       Unidad

# %% [markdown]
# # **Resumen estadístico** 📈

# %%
Image(filename='estadistica.png', width=300)

# %% [markdown]
# - .median()
# - .mode()
# - .min()
# - .max()
# - .var()
# - .std()
# - .sum()
# - .quantile()
#
#
# **Estadísticas acumulativas:**
# - .cumsum()
# - .cummin()
# - .cummax()
# - .cumprod()

# %%
supermercado_to_dic['Precio'].max()
# Out:
# 4650

# %%
def pct30(column):
  return column.quantile(0.3)

supermercado_to_dic['Precio'].agg(pct30)
# Out:
# 1200.0

# %%
supermercado_to_dic['Precio'].cumsum()
# Out:
# 0      600
# 1     2900
# 2     7550
# 3     8750
# 4    10250
# 5    11450
# Name: Precio, dtype: int64

# %% [markdown]
# # **Eliminar duplicados y value_counts()**

# %%
Image(filename='duplicados.png', width=300)

# %%
supermercado_to_dic['Producto'].value_counts(sort=True)
# Out:
# Almojábana       2
# Salchichas       1
# Leche Entera     1
# Pan con queso    1
# Pepino           1
# Name: Producto, dtype: int64

# %%
supermercado_to_dic['Producto'].value_counts(normalize=True)
# Out:
# Almojábana       0.333333
# Salchichas       0.166667
# Leche Entera     0.166667
# Pan con queso    0.166667
# Pepino           0.166667
# Name: Producto, dtype: float64

# %%
supermercado_to_dic.drop_duplicates(subset="Producto",inplace=True)
supermercado_to_dic
# Out:
#       Categoria       Producto  Precio       Fecha  Descuento Presentacion
# 0      Verduras         Pepino     600  2021-01-02      480.0       Unidad
# 1       Lacteos   Leche Entera    2300  2019-01-31     1840.0        Bolsa
# 2  Carnes Frias     Salchichas    4650  2020-05-25     3720.0      Paquete
# 3     Panaderia     Almojábana    1200  2020-08-12      960.0       Unidad
# 4     Panaderia  Pan con queso    1500  2020-11-03     1200.0       Unidad

# %%
supermercado_to_dic['Producto'].value_counts(sort=True)
# Out:
# Almojábana       1
# Salchichas       1
# Leche Entera     1
# Pan con queso    1
# Pepino           1
# Name: Producto, dtype: int64

# %% [markdown]
# # **Groupby** 🔗

# %%
Image(filename='groupby.png', width=300)

# %%
supermercado_to_dic.groupby("Categoria")["Precio"].mean()
# Out:
# Categoria
# Carnes Frias    4650
# Lacteos         2300
# Panaderia       1350
# Verduras         600
# Name: Precio, dtype: int64

# %%
supermercado_to_dic.groupby("Categoria")["Precio"].agg([min, max, sum])
# Out:
#                min   max   sum
# Categoria
# Carnes Frias  4650  4650  4650
# Lacteos       2300  2300  2300
# Panaderia     1200  1500  2700
# Verduras       600   600   600

# %%
supermercado_to_dic.groupby(["Categoria","Presentacion"])["Precio"].agg([min, max, sum])
# Out:
#                             min   max   sum
# Categoria    Presentacion
# Carnes Frias Paquete       4650  4650  4650
# Lacteos      Bolsa         2300  2300  2300
# Panaderia    Unidad        1200  1500  2700
# Verduras     Unidad         600   600   600

# %% [markdown]
# # **Pivot tables** 📄

# %%
Image(filename='pivot.png', width=300)

# %%
supermercado_to_dic.pivot_table(values="Precio", index="Categoria")
# Out:
#               Precio
# Categoria
# Carnes Frias    4650
# Lacteos         2300
# Panaderia       1350
# Verduras         600

# %%
import numpy as np
supermercado_to_dic.pivot_table(values="Precio", index="Categoria", aggfunc=np.median)
# Out:
#               Precio
# Categoria
# Carnes Frias    4650
# Lacteos         2300
# Panaderia       1350
# Verduras         600

# %%
supermercado_to_dic.pivot_table(values="Precio", index="Categoria", columns="Presentacion", fill_value=0, margins=True)
# Out:
# Presentacion  Bolsa  Paquete  Unidad   All
# Categoria
# Carnes Frias      0     4650       0  4650
# Lacteos        2300        0       0  2300
# Panaderia         0        0    1350  1350
# Verduras          0        0     600   600
# All            2300     4650    1100  2050

# %% [markdown]
# # **Índices** 🔢

# %%
Image(filename='indices.png', width=300)

# %% [markdown]
# Algunos problemas:
# - Los valores del índices son solo datos.
# - Los índices violan los principios de "datos ordenados".
# - Necesitas aprender dos sintaxis.

# %%
supermercado_to_dic.index
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
supermercado = supermercado_to_dic.set_index("Presentacion")
supermercado.head()
# Out:
#                  Categoria       Producto  Precio       Fecha  Descuento
# Presentacion
# Unidad            Verduras         Pepino     600  2021-01-02      480.0
# Bolsa              Lacteos   Leche Entera    2300  2019-01-31     1840.0
# Paquete       Carnes Frias     Salchichas    4650  2020-05-25     3720.0
# Unidad           Panaderia     Almojábana    1200  2020-08-12      960.0
# Unidad           Panaderia  Pan con queso    1500  2020-11-03     1200.0

# %%
supermercado.loc['Bolsa']
# Out:
# Categoria         Lacteos
# Producto     Leche Entera
# Precio               2300
# Fecha          2019-01-31
# Descuento            1840
# Name: Bolsa, dtype: object

# %%
supermercado.sort_index(level='Presentacion', ascending=True)
# Out:
#                  Categoria       Producto  Precio       Fecha  Descuento
# Presentacion
# Bolsa              Lacteos   Leche Entera    2300  2019-01-31     1840.0
# Paquete       Carnes Frias     Salchichas    4650  2020-05-25     3720.0
# Unidad            Verduras         Pepino     600  2021-01-02      480.0
# Unidad           Panaderia     Almojábana    1200  2020-08-12      960.0
# Unidad           Panaderia  Pan con queso    1500  2020-11-03     1200.0

# %%
supermercado.reset_index()
# Out:
#   Presentacion     Categoria       Producto  Precio       Fecha  Descuento
# 0       Unidad      Verduras         Pepino     600  2021-01-02      480.0
# 1        Bolsa       Lacteos   Leche Entera    2300  2019-01-31     1840.0
# 2      Paquete  Carnes Frias     Salchichas    4650  2020-05-25     3720.0
# 3       Unidad     Panaderia     Almojábana    1200  2020-08-12      960.0
# 4       Unidad     Panaderia  Pan con queso    1500  2020-11-03     1200.0

# %%
supermercado.reset_index(drop=True)
# Out:
#       Categoria       Producto  Precio       Fecha  Descuento
# 0      Verduras         Pepino     600  2021-01-02      480.0
# 1       Lacteos   Leche Entera    2300  2019-01-31     1840.0
# 2  Carnes Frias     Salchichas    4650  2020-05-25     3720.0
# 3     Panaderia     Almojábana    1200  2020-08-12      960.0
# 4     Panaderia  Pan con queso    1500  2020-11-03     1200.0

# %% [markdown]
# # **.iloc[]  .loc[]** 🔡🔢

# %%
Image(filename='loc.png', width=300)

# %%
supermercado_to_dic[:3]
# Out:
#       Categoria      Producto  Precio       Fecha  Descuento Presentacion
# 0      Verduras        Pepino     600  2021-01-02      480.0       Unidad
# 1       Lacteos  Leche Entera    2300  2019-01-31     1840.0        Bolsa
# 2  Carnes Frias    Salchichas    4650  2020-05-25     3720.0      Paquete

# %%
supermercado = supermercado_to_dic.set_index(["Categoria","Producto"]).sort_index()
supermercado
# Out:
#                             Precio       Fecha  Descuento Presentacion
# Categoria    Producto
# Carnes Frias Salchichas       4650  2020-05-25     3720.0      Paquete
# Lacteos      Leche Entera     2300  2019-01-31     1840.0        Bolsa
# Panaderia    Almojábana       1200  2020-08-12      960.0       Unidad
#              Pan con queso    1500  2020-11-03     1200.0       Unidad
# Verduras     Pepino            600  2021-01-02      480.0       Unidad

# %%
supermercado.loc["Lacteos":"Verduras"]
# Out:
#                          Precio       Fecha  Descuento Presentacion
# Categoria Producto
# Lacteos   Leche Entera     2300  2019-01-31     1840.0        Bolsa
# Panaderia Almojábana       1200  2020-08-12      960.0       Unidad
#           Pan con queso    1500  2020-11-03     1200.0       Unidad
# Verduras  Pepino            600  2021-01-02      480.0       Unidad

# %%
supermercado.loc[("Panaderia","Almojábana"):("Verduras", "Pepino")]
# Out:
#                          Precio       Fecha  Descuento Presentacion
# Categoria Producto
# Panaderia Almojábana       1200  2020-08-12      960.0       Unidad
#           Pan con queso    1500  2020-11-03     1200.0       Unidad
# Verduras  Pepino            600  2021-01-02      480.0       Unidad

# %%
supermercado.iloc[2:3, 1:3]
# Out:
#                            Fecha  Descuento
# Categoria Producto
# Panaderia Almojábana  2020-08-12      960.0

# %% [markdown]
# # **Visualización** 📊

# %%
Image(filename='visualizacion.png', width=300)

# %% [markdown]
# - Hist
# - Bar
# - Line
# - Scatter

# %%
import matplotlib.pyplot as plt

# %%
supermercado_to_dic['Precio'].hist(bins=20,alpha=0.7)
plt.legend(["Precios"])
plt.show()

# %%
precios = supermercado_to_dic.groupby("Categoria")["Precio"].mean()

precios.plot(kind="bar", title="Media del precio de productos")
plt.show()

# %%
supermercado_to_dic.plot(x="Fecha", y="Precio",kind="line",rot=45)
plt.show()

# %%
supermercado_to_dic.plot(x="Fecha", y="Precio",kind="scatter")
plt.show()

# %% [markdown]
# # **Missing values** ❌

# %%
Image(filename='missing.png', width=300)

# %% [markdown]
# Detectar Missing Values:

# %%
supermercado_to_dic.isna()
# Out:
#    Categoria  Producto  Precio  Fecha  Descuento  Presentacion
# 0      False     False   False  False      False         False
# 1      False     False   False  False      False         False
# 2      False     False   False  False      False         False
# 3      False     False   False  False      False         False
# 4      False     False   False  False      False         False

# %% [markdown]
# Añadir un nuevo producto con un dato faltante:

# %%
supermercado_to_dic = supermercado_to_dic.append({'Categoria' : 'Verduras' , 'Producto' : 'Tomate'} , ignore_index=True, )
supermercado_to_dic
# Out:
#       Categoria       Producto  Precio       Fecha  Descuento Presentacion
# 0      Verduras         Pepino   600.0  2021-01-02      480.0       Unidad
# 1       Lacteos   Leche Entera  2300.0  2019-01-31     1840.0        Bolsa
# 2  Carnes Frias     Salchichas  4650.0  2020-05-25     3720.0      Paquete
# 3     Panaderia     Almojábana  1200.0  2020-08-12      960.0       Unidad
# 4     Panaderia  Pan con queso  1500.0  2020-11-03     1200.0       Unidad
# 5      Verduras         Tomate     NaN         NaN        NaN          NaN
# 6      Verduras         Tomate     NaN         NaN        NaN          NaN

# %%
supermercado_to_dic.isna().any()
# Out:
# Categoria       False
# Producto        False
# Precio           True
# Fecha            True
# Descuento        True
# Presentacion     True
# dtype: bool

# %%
supermercado_to_dic.isna().sum()
# Out:
# Categoria       0
# Producto        0
# Precio          2
# Fecha           2
# Descuento       2
# Presentacion    2
# dtype: int64

# %% [markdown]
# Eliminar valores faltantes:

# %%
supermercado_to_dic.dropna(inplace=True)
supermercado_to_dic
# Out:
#       Categoria       Producto  Precio       Fecha  Descuento Presentacion
# 0      Verduras         Pepino   600.0  2021-01-02      480.0       Unidad
# 1       Lacteos   Leche Entera  2300.0  2019-01-31     1840.0        Bolsa
# 2  Carnes Frias     Salchichas  4650.0  2020-05-25     3720.0      Paquete
# 3     Panaderia     Almojábana  1200.0  2020-08-12      960.0       Unidad
# 4     Panaderia  Pan con queso  1500.0  2020-11-03     1200.0       Unidad

# %% [markdown]
# Reemplazar valores faltanes:

# %%
supermercado_to_dic = supermercado_to_dic.append({'Categoria' : 'Verduras' , 'Producto' : 'Cebolla', 'Precio' : 400} , ignore_index=True)
supermercado_to_dic
# Out:
#       Categoria       Producto  Precio       Fecha  Descuento Presentacion
# 0      Verduras         Pepino   600.0  2021-01-02      480.0       Unidad
# 1       Lacteos   Leche Entera  2300.0  2019-01-31     1840.0        Bolsa
# 2  Carnes Frias     Salchichas  4650.0  2020-05-25     3720.0      Paquete
# 3     Panaderia     Almojábana  1200.0  2020-08-12      960.0       Unidad
# 4     Panaderia  Pan con queso  1500.0  2020-11-03     1200.0       Unidad
# 5      Verduras        Cebolla   400.0         NaN        NaN          NaN

# %%
supermercado_to_dic.fillna(0)
# Out:
#       Categoria       Producto  Precio       Fecha  Descuento Presentacion
# 0      Verduras         Pepino   600.0  2021-01-02      480.0       Unidad
# 1       Lacteos   Leche Entera  2300.0  2019-01-31     1840.0        Bolsa
# 2  Carnes Frias     Salchichas  4650.0  2020-05-25     3720.0      Paquete
# 3     Panaderia     Almojábana  1200.0  2020-08-12      960.0       Unidad
# 4     Panaderia  Pan con queso  1500.0  2020-11-03     1200.0       Unidad
# 5      Verduras        Cebolla   400.0           0        0.0            0

# %% [markdown]
# # **CSV** 🧾

# %%
Image(filename='csv.png', width=300)

# %% [markdown]
# CSV: Archivo separado por comas

# %% [markdown]
# Leer un archivo .csv como DataFrame:

# %%
creditosAlemania = pd.read_csv("datos_credito_alemania.csv")
creditosAlemania.head()
# Out:
#    Unnamed: 0   Age     Sex  ...  Duration              Purpose  Risk
# 0         0.0  67.0    male  ...       6.0             radio/TV  good
# 1         1.0  22.0  female  ...      48.0             radio/TV   bad
# 2         2.0  49.0    male  ...      12.0            education  good
# 3         3.0  45.0    male  ...      42.0  furniture/equipment  good
# 4         4.0  53.0    male  ...      24.0                  car   bad
#
# [5 rows x 11 columns]

# %% [markdown]
# Guardar un DataFrame como archivo .csv

# %%
supermercado_to_dic.to_csv("supermercado.csv")

# %%
Image(filename='gracias.png', width=900)
